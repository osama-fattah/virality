# %%
import math
import string
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import string as st
from urllib.request import urlopen
from bs4 import BeautifulSoup
# %matplotlib inline

# %%
# here i am taking the input fron the used on how many days they want to scan as database
print("enter the number, but be careful, because this process depends on your internet speed and can take a long time(an hour) if the input exceeds 5, For testing purposes use 1")
inp = input("enter the number of days from today, you want to include in the data set (maximum is 6690, Each data set has approximately  500 data points) : ")
# Out:
# enter the number of days from today, you want to include in the data set (maximum is 6690, Each data set has approximately  500 data points) : 2

# %%
# here i am extracting the headlines from the archives of thetimesofindia.com
flst=[]
rinp=int(inp)
for i in range(rinp) :
    url = "https://timesofindia.indiatimes.com/archivelist/starttime-"+str(43948-i)+".cms"
    html = urlopen(url)
    soup = BeautifulSoup(html, 'lxml')
    type(soup)
    # Get the title
    title = soup.title
    #print(title)
    # Print out the text
    text = soup.get_text()
    text=str(text)
    in_str=(text.find('DATEArchives')+43)
    en_str=(text.find('LATEST'))
    fin_str=text[in_str:en_str]
    fint=fin_str.replace(' ','%20')
    lst=fint.split('%20%20')
    lsts=lst[0].split('\xa0\xa0')
    flst=flst+lsts
print(flst)
# Out:
# ['New%20anthem%20celebrating%20the%20feats%20of%20Covid%20warriors', 'THEMXXNLIGHT:%20Performing%20with%20Wiz%20Khalifa%20in%20India%20was%20definitely%20one%20of%20the%20greatest%20experiences%20of%20our%20lives', 'Malavika%20Mohanan:%20My%20brother%20is%20stuck%20in%20the%20UK%20and%20it’s%20taking%20a%20toll%20on%20him%20mentally', '‘Every%20patient%20who%20recovers%20from%20Covid-19%20must%20donate%20their%20plasma’', '‘I%20feel%20it%20was%20my%20social%20responsibility%20to%20donate%20blood%20plasma’', 'I%20am%20not%20desperate%20to%20leave%20India:%20Juan%20Tusso', 'Aarohi%20Patel%20wants%20to%20produce%20web-content', 'Aarohi%20Patel%20wants%20to%20produce%20web-content', '#IndoorRun:%20Even%20lockdown%20can’t%20stop%20these%20running%20enthusiasts', '#IndoorRun:%20Even%20lockdown%20can’t%20stop%20these%20running%20enthusiasts', '#LifeInTheLockdown%20Bhumi%20Pednekar:%20Going%20around%20my%20little%20garden%20adds%20joy%20to%20my%20mornings', 'Government%20may%20stand%20guaran
# ...

# %%
# here i am extracting the number of hits from the google search page
import requests 
nlst=[]
for k in range(0,len(flst)):
    print('|',end='')
print("wait till the bar loads till this stage")
print(" ")
from bs4 import BeautifulSoup  
for j in range(0,len(flst)) :
    url='https://www.google.com/search?q='+flst[j]
    resp=requests.get(url)  
    soup=BeautifulSoup(resp.text,'html.parser')     
    soup=str(soup)
    nlst.append(len(soup))
    print('|',end='')
print(nlst)
# Out:
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ...

# %%
# here i am scaling the hits to make a score out of 1000
nls=np.array(nlst)
lt_n=(1000*(nls-min(nls)+1)/max(nls))
for p in range(0,len(lt_n)):
    lt_n[p]=int(round(lt_n[p]))
lt_n=lt_n.astype(np.int64)
print(lt_n)
# Out:
# [ 57 127 113 ...  90  80   0]

# %%
# Here i am finding the average length of news headlines
lt_t=np.array(flst)
nu=[]
for g in range(0,len(lt_t)):
    nu.append(len(lt_t[g]))
nuu=np.array(nu)
avg=sum(nuu)/len(nuu)
avg=round(avg)
avg=avg.astype(np.int64)
print("average=",avg)
inu=input("how may letters do you want to check(should be less than avg): ")
avg=int(inu)
print(avg)
# Out:
# average= 72
# how may letters do you want to check(should be less than avg)20
# 20

# %%
# here i am replacing the string charecters with its ascii number
string.ascii_letters
lt=np.array(lt_t)
result_array = np.array([])
#lto=[len(lt_t)][avg]
for e in range(0,len(lt_t)):
    lt_t[e]=lt_t[e].replace('%20',' ')
for r in range(0,len(lt_t)):
    if len(lt_t[r])>avg :
        lt_t[r]=lt_t[r][:avg]
    else :
        for c in range(len(lt_t[r]),avg) :
            lt_t[r]=lt_t[r]+(random.choice(string.ascii_letters))
for fr in range(0,len(lt_t)):
    for cr in range(0,len(lt_t[fr])):
        result_array = np.append(result_array,ord(lt_t[fr][cr]))
for rty in range(0,len(lt_t)):
    result_array=result_array.astype(np.int64)
azs=len(result_array)/avg
azs=int(azs)
news =  np.split(result_array, azs)
print(news)
hits=lt_n
# Out:
# [array([ 78, 101, 119,  32,  97, 110, 116, 104, 101, 109,  32,  99, 101,
#        108, 101,  98, 114,  97, 116, 105], dtype=int64), array([ 84,  72,  69,  77,  88,  88,  78,  76,  73,  71,  72,  84,  58,
#         32,  80, 101, 114, 102, 111, 114], dtype=int64), array([ 77,  97, 108,  97, 118, 105, 107,  97,  32,  77, 111, 104,  97,
#        110,  97, 110,  58,  32,  77, 121], dtype=int64), array([8216,   69,  118,  101,  114,  121,   32,  112,   97,  116,  105,
#         101,  110,  116,   32,  119,  104,  111,   32,  114], dtype=int64), array([8216,   73,   32,  102,  101,  101,  108,   32,  105,  116,   32,
#         119,   97,  115,   32,  109,  121,   32,  115,  111], dtype=int64), array([ 73,  32,  97, 109,  32, 110, 111, 116,  32, 100, 101, 115, 112,
#        101, 114,  97, 116, 101,  32, 116], dtype=int64), array([ 65,  97, 114, 111, 104, 105,  32,  80,  97, 116, 101, 108,  32,
# ...

# %%
# so the 2 data sets are hits AND news
# here we are checking if both of them have the same length
print(len(hits))
print(len(news))
news=np.array(news)
hits=np.array(hits)
X=news
Y=hits
# Out:
# 1002
# 1002

# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import sklearn.datasets
import sklearn.linear_model
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import sklearn.datasets
import sklearn.linear_model

def plot_decision_boundary(model, X, y):
    # Set min and max values and give it some padding
    x_min, x_max = X[0, :].min() - 1, X[0, :].max() + 1
    y_min, y_max = X[1, :].min() - 1, X[1, :].max() + 1
    h = 0.01
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole grid
    Z = model(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.ylabel('x2')
    plt.xlabel('x1')
    plt.scatter(X[0, :], X[1, :], c=y, cmap=plt.cm.Spectral)


def sigmoid(x):
    s = 1/(1+np.exp(-x))
    return s

def load_planar_dataset():
    m = 400
    N = int(m/2)
    D = 2
    X = np.zeros((m,D))
    Y = np.zeros((m,1), dtype='uint8') 
    a = 4 

    for j in range(2):
        ix = range(N*j,N*(j+1))
        t = np.linspace(j*3.12,(j+1)*3.12,N) + np.random.randn(N)*0.2 # theta
        r = a*np.sin(4*t) + np.random.randn(N)*0.2 # radius
        X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
        Y[ix] = j

    X = X.T
    Y = Y.T

    return X, Y

def load_extra_datasets():  
    N = 200
    noisy_circles = sklearn.datasets.make_circles(n_samples=N, factor=.5, noise=.3)
    noisy_moons = sklearn.datasets.make_moons(n_samples=N, noise=.2)
    blobs = sklearn.datasets.make_blobs(n_samples=N, random_state=5, n_features=2, centers=6)
    gaussian_quantiles = sklearn.datasets.make_gaussian_quantiles(mean=None, cov=0.5, n_samples=N, n_features=2, n_classes=2, shuffle=True, random_state=None)
    no_structure = np.random.rand(N, 2), np.random.rand(N, 2)

    return noisy_circles, noisy_moons, blobs, gaussian_quantiles, no_structure

# %%
X=X.T
Y=np.reshape(Y,(1,len(hits)))
shape_X = np.shape(X)
shape_Y = np.shape(Y)
m = np.size(Y)
# Out:
# The shape of X is: (20, 1002)
# The shape of Y is: (1, 1002)
# I have m = 1002 training examples!

# %%
# Train the logistic regression classifier
#clf = sklearn.linear_model.LogisticRegressionCV();
#clf.fit(X.T, Y.T);

# %%
def layer_sizes(X, Y):
    n_x = np.shape(X)[0]
    n_h = 4
    n_y = np.shape(Y)[0]
    return (n_x, n_h, n_y)

# %%
def initialize_parameters(n_x, n_h, n_y):
    np.random.seed(2)
    
    W1 = np.random.randn(n_h,n_x)*0.01
    b1 = np.zeros((n_h,1))
    W2 = np.random.randn(n_y,n_h)*0.01
    b2 = np.zeros((n_y,1))
    
    assert (W1.shape == (n_h, n_x))
    assert (b1.shape == (n_h, 1))
    assert (W2.shape == (n_y, n_h))
    assert (b2.shape == (n_y, 1))
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
def forward_propagation(X, parameters):

    W1 = parameters["W1"]
    b1 = parameters["b1"]
    W2 = parameters["W2"]
    b2 = parameters["b2"]
    Z1 = np.dot(W1,X)+b1
    A1 = np.tanh(Z1)
    Z2 = np.dot(W2,A1)+b2
    A2 = sigmoid(Z2)
    
    #assert(A2.shape == (1, X.shape[1]))
    
    cache = {"Z1": Z1,
             "A1": A1,
             "Z2": Z2,
             "A2": A2}
    
    return A2, cache

# %%
def compute_cost(A2, Y, parameters):
    m = Y.shape[1] # number of example
    logprobs = np.multiply(np.log(A2),Y)+np.multiply((1-Y),np.log(1-A2))
    cost =-1/m* np.sum(logprobs)
    cost = float(np.squeeze(cost))  # makes sure cost is the dimension we expect.                                     # E.g., turns [[17]] into 17 
    assert(isinstance(cost, float))    
    return cost

# %%
def backward_propagation(parameters, cache, X, Y):
    m = X.shape[1]

    W1 = parameters["W1"]
    W2 = parameters["W2"]

    A1 = cache["A1"]
    A2 = cache["A2"]
    
    dZ2 = A2-Y
    dW2 = 1/m*np.dot(dZ2,A1.T)
    db2 = 1/m*np.sum(dZ2,axis=1,keepdims=True)
    dZ1 = np.multiply(np.dot(W2.T,dZ2),(1 - np.power(A1, 2)))
    dW1 = 1/m*np.dot(dZ1,X.T)
    db1 = 1/m*np.sum(dZ1,axis=1,keepdims=True)
    
    grads = {"dW1": dW1,
             "db1": db1,
             "dW2": dW2,
             "db2": db2}
    
    return grads

# %%
def update_parameters(parameters, grads, learning_rate = 1.2):

    W1 = parameters["W1"]
    b1 = parameters["b1"]
    W2 = parameters["W2"]
    b2 = parameters["b2"]

    dW1 = grads["dW1"]
    db1 = grads["db1"]
    dW2 = grads["dW2"]
    db2 = grads["db2"]

    W1 = W1-learning_rate*dW1
    b1 = b1-learning_rate*db1
    W2 = W2-learning_rate*dW2
    b2 = b2-learning_rate*db2
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
def nn_model(X, Y, n_h, num_iterations = 10000, print_cost=False):
    n_x = layer_sizes(X, Y)[0]
    n_y = layer_sizes(X, Y)[2]

    parameters = initialize_parameters(n_x, n_h, n_y)

    for i in range(0, num_iterations):
         
        A2, cache = forward_propagation(X, parameters)
        
        cost = compute_cost(A2, Y, parameters)
 
        grads = backward_propagation(parameters, cache, X, Y)
        Outputs: "parameters".
        parameters = update_parameters(parameters, grads, learning_rate = 1.2)

        if print_cost and i % 1000 == 0:
            print ("Cost after iteration %i: %f" %(i, cost))

    return parameters

# %%
def predict(parameters, X):

    A2, cache = forward_propagation(X, parameters)
    predictions = (A2)
    return predictions

# %%
D=[[1,2,4,6,545,53,43,4,45,43,53,212,542,43,55,56,34,34,23,23]]
D=np.array(D)
n_x,n_h,n_y=layer_sizes(X, Y)
parameters=nn_model(X, Y, n_h, num_iterations = 10000, print_cost=False)
pre=predict(parameters,X )
print(pre[0][20])
# Out:
# C:\Users\osama\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: RuntimeWarning: divide by zero encountered in log
# 1.0
